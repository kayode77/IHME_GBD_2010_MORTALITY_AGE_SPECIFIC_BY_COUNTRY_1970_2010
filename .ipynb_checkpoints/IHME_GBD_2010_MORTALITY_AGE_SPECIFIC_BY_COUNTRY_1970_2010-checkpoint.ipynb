# %%
import pandas as pd
A=pd.read_csv('IHME_GBD_2010_MORTALITY_AGE_SPECIFIC_BY_COUNTRY_1970_2010.csv' )
A.head()
# Out:
#   Country Code Country Name  Year  Age Group     Sex Number of Deaths  \
# 0          AFG  Afghanistan  1970   0-6 days    Male           19,241
# 1          AFG  Afghanistan  1970   0-6 days  Female           12,600
# 2          AFG  Afghanistan  1970   0-6 days    Both           31,840
# 3          AFG  Afghanistan  1970  7-27 days    Male           15,939
# 4          AFG  Afghanistan  1970  7-27 days  Female           11,287
#
#   Death Rate Per 100,000
# 0             318,292.90
# 1             219,544.20
# 2             270,200.70
# 3              92,701.00
# 4              68,594.50

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58905 entries, 0 to 58904
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country Code            58905 non-null  object
#  1   Country Name            58905 non-null  object
#  2   Year                    58905 non-null  int64
#  3   Age Group               58905 non-null  object
#  4   Sex                     58905 non-null  object
#  5   Number of Deaths        58905 non-null  object
#  6   Death Rate Per 100,000  58905 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 3.1+ MB

# %%
A["Numeric_Number of Deaths"] = A["Number of Deaths"].apply(lambda x: int(x.replace(",", "")))
A["Numeric_Death Rate Per 100,000"] = A["Death Rate Per 100,000"].apply(lambda x: x.replace(",", "")).astype('float')

# %%
A.head()
# Out:
#   Country Code Country Name  Year  Age Group     Sex Number of Deaths  \
# 0          AFG  Afghanistan  1970   0-6 days    Male           19,241
# 1          AFG  Afghanistan  1970   0-6 days  Female           12,600
# 2          AFG  Afghanistan  1970   0-6 days    Both           31,840
# 3          AFG  Afghanistan  1970  7-27 days    Male           15,939
# 4          AFG  Afghanistan  1970  7-27 days  Female           11,287
#
#   Death Rate Per 100,000  Numeric_Number of Deaths  \
# 0             318,292.90                     19241
# 1             219,544.20                     12600
# 2             270,200.70                     31840
# 3              92,701.00                     15939
# 4              68,594.50                     11287
#
#    Numeric_Death Rate Per 100,000
# 0                        318292.9
# 1                        219544.2
# 2                        270200.7
# 3                         92701.0
# 4                         68594.5

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58905 entries, 0 to 58904
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country Code                    58905 non-null  object
#  1   Country Name                    58905 non-null  object
#  2   Year                            58905 non-null  int64
#  3   Age Group                       58905 non-null  object
#  4   Sex                             58905 non-null  object
#  5   Number of Deaths                58905 non-null  object
#  6   Death Rate Per 100,000          58905 non-null  object
#  7   Numeric_Number of Deaths        58905 non-null  int64
#  8   Numeric_Death Rate Per 100,000  58905 non-null  float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 4.0+ MB

# %%
A.describe()
# Out:
#                Year  Numeric_Number of Deaths  Numeric_Death Rate Per 100,000
# count  58905.000000              5.890500e+04                    58905.000000
# mean    1990.000000              1.610994e+04                     7062.866458
# std       14.142256              1.543293e+05                    24582.548947
# min     1970.000000              0.000000e+00                        5.500000
# 25%     1980.000000              1.660000e+02                      210.300000
# 50%     1990.000000              1.020000e+03                      825.000000
# 75%     2000.000000              4.460000e+03                     3611.800000
# max     2010.000000              9.938487e+06                   423790.200000

# %%
A1 = A.set_index("Country Name")
A1 = A1.sort_index()
A1.head()
# Out:
#              Country Code  Year    Age Group     Sex Number of Deaths  \
# Country Name
# Afghanistan           AFG  1970     0-6 days    Male           19,241
# Afghanistan           AFG  2000  25-29 years  Female            4,877
# Afghanistan           AFG  2000  25-29 years    Male            3,556
# Afghanistan           AFG  2000  20-24 years    Both            8,470
# Afghanistan           AFG  2000  20-24 years  Female            4,519
#
#              Death Rate Per 100,000  Numeric_Number of Deaths  \
# Country Name
# Afghanistan              318,292.90                     19241
# Afghanistan                   632.8                      4877
# Afghanistan                   422.3                      3556
# Afghanistan                   433.6                      8470
# Afghanistan                   483.1                      4519
#
#               Numeric_Death Rate Per 100,000
# Country Name
# Afghanistan                         318292.9
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
g = sns.PairGrid(A)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);
plt.show()

# %%
A['Country Name'].value_counts()
# Out:
# Qatar                              315
# Bahamas                            315
# Estonia                            315
# Philippines                        315
# Burkina Faso                       315
#                                   ...
# Uruguay                            315
# Timor-Leste                        315
# Azerbaijan                         315
# Belize                             315
# Micronesia, Federated States of    315
# Name: Country Name, Length: 187, dtype: int64

# %%
A['Year'].value_counts()
# Out:
# 1980    11781
# 2010    11781
# 1970    11781
# 2000    11781
# 1990    11781
# Name: Year, dtype: int64

# %%
A2 = A[['Numeric_Number of Deaths','Numeric_Death Rate Per 100,000']].groupby(A['Country Name']).sum()
A2
# Out:
#               Numeric_Number of Deaths  Numeric_Death Rate Per 100,000
# Country Name
# Afghanistan                    5687183                       4429976.4
# Albania                         349413                        962339.2
# Algeria                        3322568                       2481166.7
# Andorra                           8215                        619746.6
# Angola                         3405986                       3389346.8
# ...                                ...                             ...
# Venezuela                      1891674                       1386227.8
# Viet Nam                       8947408                       1774119.5
# Yemen                          2697944                       3787465.4
# Zambia                         2325708                       2817261.6
# Zimbabwe                       2162430                       2564607.4
#
# [187 rows x 2 columns]

# %% [markdown]
# # Analysis of data from Afghanistan

# %%
# let's check the Country Name in line with this parameters:'Year','Age Group','Sex','Numeric_Number of Deaths','Numeric_Death Rate Per 100,000'
def Country_Name(x):
    return A[(A['Country Name'] == x)][['Year','Age Group','Sex','Numeric_Number of Deaths','Numeric_Death Rate Per 100,000']]
Country_Name("Afghanistan")
# Out:
#      Year  Age Group     Sex  Numeric_Number of Deaths  \
# 0    1970   0-6 days    Male                     19241
# 1    1970   0-6 days  Female                     12600
# 2    1970   0-6 days    Both                     31840
# 3    1970  7-27 days    Male                     15939
# 4    1970  7-27 days  Female                     11287
# ..    ...        ...     ...                       ...
# 310  2010  80+ years  Female                      6892
# 311  2010  80+ years    Both                     11757
# 312  2010   All ages    Male                    151509
# 313  2010   All ages  Female                    150654
# 314  2010   All ages    Both                    302163
#
#      Numeric_Death Rate Per 100,000
# 0                          318292.9
# 1                          219544.2
# 2                          270200.7
# 3                           92701.0
# 4                           68594.5
# ..                              ...
# 310                         20370.1
# ...

# %%
# People that are Males in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Sex == 'Male']
# Out:
#      Year    Age Group   Sex  Numeric_Number of Deaths  \
# 0    1970     0-6 days  Male                     19241
# 3    1970    7-27 days  Male                     15939
# 6    1970  28-364 days  Male                     37513
# 9    1970    1-4 years  Male                     36694
# 12   1970    5-9 years  Male                      3467
# ..    ...          ...   ...                       ...
# 300  2010  65-69 years  Male                      8591
# 303  2010  70-74 years  Male                      7726
# 306  2010  75-79 years  Male                      5740
# 309  2010    80+ years  Male                      4865
# 312  2010     All ages  Male                    151509
#
#      Numeric_Death Rate Per 100,000
# 0                          318292.9
# 3                           92701.0
# 6                           15040.1
# 9                            4288.2
# 12                            396.2
# ..                              ...
# 300                          5291.9
# ...

# %%
# People that are Females in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Sex == 'Female']
# Out:
#      Year    Age Group     Sex  Numeric_Number of Deaths  \
# 1    1970     0-6 days  Female                     12600
# 4    1970    7-27 days  Female                     11287
# 7    1970  28-364 days  Female                     32113
# 10   1970    1-4 years  Female                     32848
# 13   1970    5-9 years  Female                      2492
# ..    ...          ...     ...                       ...
# 301  2010  65-69 years  Female                      9500
# 304  2010  70-74 years  Female                      9701
# 307  2010  75-79 years  Female                      7679
# 310  2010    80+ years  Female                      6892
# 313  2010     All ages  Female                    150654
#
#      Numeric_Death Rate Per 100,000
# 1                          219544.2
# 4                           68594.5
# 7                           13411.8
# 10                           4022.9
# 13                            306.0
# ..                              ...
# ...

# %%
# People that are Both(Sex) in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Sex == 'Both']
# Out:
#      Year    Age Group   Sex  Numeric_Number of Deaths  \
# 2    1970     0-6 days  Both                     31840
# 5    1970    7-27 days  Both                     27226
# 8    1970  28-364 days  Both                     69626
# 11   1970    1-4 years  Both                     69542
# 14   1970    5-9 years  Both                      5959
# ..    ...          ...   ...                       ...
# 302  2010  65-69 years  Both                     18090
# 305  2010  70-74 years  Both                     17427
# 308  2010  75-79 years  Both                     13419
# 311  2010    80+ years  Both                     11757
# 314  2010     All ages  Both                    302163
#
#      Numeric_Death Rate Per 100,000
# 2                          270200.7
# 5                           80912.5
# 8                           14242.6
# 11                           4158.6
# 14                            352.7
# ..                              ...
# 302                          5549.5
# ...

# %%
# 1970 Year of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Year == 1970]
# Out:
#     Year  Age Group     Sex  Numeric_Number of Deaths  \
# 0   1970   0-6 days    Male                     19241
# 1   1970   0-6 days  Female                     12600
# 2   1970   0-6 days    Both                     31840
# 3   1970  7-27 days    Male                     15939
# 4   1970  7-27 days  Female                     11287
# ..   ...        ...     ...                       ...
# 58  1970  80+ years  Female                      2180
# 59  1970  80+ years    Both                      3856
# 60  1970   All ages    Male                    153656
# 61  1970   All ages  Female                    138181
# 62  1970   All ages    Both                    291837
#
#     Numeric_Death Rate Per 100,000
# 0                         318292.9
# 1                         219544.2
# 2                         270200.7
# 3                          92701.0
# 4                          68594.5
# ..                             ...
# 58                         21197.1
# ...

# %%
# 1980 Year of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Year == 1980]
# Out:
#      Year  Age Group     Sex  Numeric_Number of Deaths  \
# 63   1980   0-6 days    Male                     16152
# 64   1980   0-6 days  Female                     10838
# 65   1980   0-6 days    Both                     26991
# 66   1980  7-27 days    Male                     12551
# 67   1980  7-27 days  Female                      9217
# ..    ...        ...     ...                       ...
# 121  1980  80+ years  Female                      2831
# 122  1980  80+ years    Both                      4924
# 123  1980   All ages    Male                    154935
# 124  1980   All ages  Female                    137110
# 125  1980   All ages    Both                    292045
#
#      Numeric_Death Rate Per 100,000
# 63                         235901.0
# 64                         167053.3
# 65                         202403.9
# 66                          63362.9
# 67                          48823.2
# ..                              ...
# 121                         21657.7
# ...

# %%
# 1990 Year of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Year == 1990]
# Out:
#      Year  Age Group     Sex  Numeric_Number of Deaths  \
# 126  1990   0-6 days    Male                     12635
# 127  1990   0-6 days  Female                      8636
# 128  1990   0-6 days    Both                     21271
# 129  1990  7-27 days    Male                      8325
# 130  1990  7-27 days  Female                      6203
# ..    ...        ...     ...                       ...
# 184  1990  80+ years  Female                      2680
# 185  1990  80+ years    Both                      4599
# 186  1990   All ages    Male                    103305
# 187  1990   All ages  Female                     97331
# 188  1990   All ages    Both                    200636
#
#      Numeric_Death Rate Per 100,000
# 126                        174654.7
# 127                        126115.8
# 128                        151050.5
# 129                         39454.3
# 130                         30916.8
# ..                              ...
# 184                         21019.7
# ...

# %%
# 2000 Year of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Year == 2000]
# Out:
#      Year  Age Group     Sex  Numeric_Number of Deaths  \
# 189  2000   0-6 days    Male                     19345
# 190  2000   0-6 days  Female                     13222
# 191  2000   0-6 days    Both                     32567
# 192  2000  7-27 days    Male                     12365
# 193  2000  7-27 days  Female                      9189
# ..    ...        ...     ...                       ...
# 247  2000  80+ years  Female                      5138
# 248  2000  80+ years    Both                      8698
# 249  2000   All ages    Male                    169558
# 250  2000   All ages  Female                    165558
# 251  2000   All ages    Both                    335117
#
#      Numeric_Death Rate Per 100,000
# 189                        168778.1
# 190                        121860.6
# 191                        145956.2
# 192                         36914.4
# 193                         28855.1
# ..                              ...
# 247                         22266.2
# ...

# %%
# 2010 Year of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan").Year == 2010]
# Out:
#      Year  Age Group     Sex  Numeric_Number of Deaths  \
# 252  2010   0-6 days    Male                     17163
# 253  2010   0-6 days  Female                     11904
# 254  2010   0-6 days    Both                     29067
# 255  2010  7-27 days    Male                      7639
# 256  2010  7-27 days  Female                      5864
# ..    ...        ...     ...                       ...
# 310  2010  80+ years  Female                      6892
# 311  2010  80+ years    Both                     11757
# 312  2010   All ages    Male                    151509
# 313  2010   All ages  Female                    150654
# 314  2010   All ages    Both                    302163
#
#      Numeric_Death Rate Per 100,000
# 252                        127190.9
# 253                         93233.3
# 254                        110681.5
# 255                         19244.2
# 256                         15557.2
# ..                              ...
# 310                         20370.1
# ...

# %%
# Year,age group ,and Sex(Male) of death in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')&(Country_Name("Afghanistan").Sex =='Male')]
# Out:
#    Year Age Group   Sex  Numeric_Number of Deaths  \
# 0  1970  0-6 days  Male                     19241
#
#    Numeric_Death Rate Per 100,000
# 0                        318292.9

# %%
# Year and age group of death in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')]
# Out:
#    Year Age Group     Sex  Numeric_Number of Deaths  \
# 0  1970  0-6 days    Male                     19241
# 1  1970  0-6 days  Female                     12600
# 2  1970  0-6 days    Both                     31840
#
#    Numeric_Death Rate Per 100,000
# 0                        318292.9
# 1                        219544.2
# 2                        270200.7

# %%
# Year and age group(7-27 days) of death in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan")['Age Group'] == '7-27 days')]
# Out:
#    Year  Age Group     Sex  Numeric_Number of Deaths  \
# 3  1970  7-27 days    Male                     15939
# 4  1970  7-27 days  Female                     11287
# 5  1970  7-27 days    Both                     27226
#
#    Numeric_Death Rate Per 100,000
# 3                         92701.0
# 4                         68594.5
# 5                         80912.5

# %%
# Year and Sex(Male) of death in Afghanistan in 1970:
Af=Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Male')]
Af
# Out:
#     Year    Age Group   Sex  Numeric_Number of Deaths  \
# 0   1970     0-6 days  Male                     19241
# 3   1970    7-27 days  Male                     15939
# 6   1970  28-364 days  Male                     37513
# 9   1970    1-4 years  Male                     36694
# 12  1970    5-9 years  Male                      3467
# 15  1970  10-14 years  Male                      1723
# 18  1970  15-19 years  Male                      1816
# 21  1970  20-24 years  Male                      2240
# 24  1970  25-29 years  Male                      2050
# 27  1970  30-34 years  Male                      2038
# 30  1970  35-39 years  Male                      2242
# 33  1970  40-44 years  Male                      2528
# 36  1970  45-49 years  Male                      2993
# 39  1970  50-54 years  Male                      3569
# 42  1970  55-59 years  Male                      3911
# 45  1970  60-64 years  Male                      4239
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fig, ax = plt.subplots(1, 1, figsize=(10, 15))
ax.set_title('Plot of Numeric_Number of Deaths among the Males over the days')
sns.barplot(x="Numeric_Number of Deaths", y="Age Group", hue="Sex", data=Af)

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fig, ax = plt.subplots(1, 1, figsize=(10, 18))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Males over the days')
sns.barplot(x="Numeric_Death Rate Per 100,000", y="Age Group", hue="Sex", data=Af)

# %%
# Year and Sex(Female) of death in Afghanistan in 1970:
Af1=Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Female')]
Af1
# Out:
#     Year    Age Group     Sex  Numeric_Number of Deaths  \
# 1   1970     0-6 days  Female                     12600
# 4   1970    7-27 days  Female                     11287
# 7   1970  28-364 days  Female                     32113
# 10  1970    1-4 years  Female                     32848
# 13  1970    5-9 years  Female                      2492
# 16  1970  10-14 years  Female                      1806
# 19  1970  15-19 years  Female                      1902
# 22  1970  20-24 years  Female                      2630
# 25  1970  25-29 years  Female                      2889
# 28  1970  30-34 years  Female                      2799
# 31  1970  35-39 years  Female                      3358
# 34  1970  40-44 years  Female                      2908
# 37  1970  45-49 years  Female                      2909
# 40  1970  50-54 years  Female                      3300
# 43  1970  55-59 years  Female                      3532
# 46  1970  60-64 years  Female                      4514
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fig, ax = plt.subplots(1, 1, figsize=(10, 15))
ax.set_title('Plot of Numeric_Number of Deaths among the Males over the days')
sns.barplot(x="Numeric_Number of Deaths", y="Age Group", hue="Sex", data=Af1)

# %%
# Year and Sex(Both) of death in Afghanistan in 1970:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Both')]
# Out:
#     Year    Age Group   Sex  Numeric_Number of Deaths  \
# 2   1970     0-6 days  Both                     31840
# 5   1970    7-27 days  Both                     27226
# 8   1970  28-364 days  Both                     69626
# 11  1970    1-4 years  Both                     69542
# 14  1970    5-9 years  Both                      5959
# 17  1970  10-14 years  Both                      3529
# 20  1970  15-19 years  Both                      3718
# 23  1970  20-24 years  Both                      4870
# 26  1970  25-29 years  Both                      4939
# 29  1970  30-34 years  Both                      4838
# 32  1970  35-39 years  Both                      5600
# 35  1970  40-44 years  Both                      5437
# 38  1970  45-49 years  Both                      5902
# 41  1970  50-54 years  Both                      6870
# 44  1970  55-59 years  Both                      7443
# 47  1970  60-64 years  Both                      8752
# ...

# %%
# Age Group of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan")['Age Group'].str.endswith("days")]
# Out:
#      Year    Age Group     Sex  Numeric_Number of Deaths  \
# 0    1970     0-6 days    Male                     19241
# 1    1970     0-6 days  Female                     12600
# 2    1970     0-6 days    Both                     31840
# 3    1970    7-27 days    Male                     15939
# 4    1970    7-27 days  Female                     11287
# 5    1970    7-27 days    Both                     27226
# 6    1970  28-364 days    Male                     37513
# 7    1970  28-364 days  Female                     32113
# 8    1970  28-364 days    Both                     69626
# 63   1980     0-6 days    Male                     16152
# 64   1980     0-6 days  Female                     10838
# 65   1980     0-6 days    Both                     26991
# 66   1980    7-27 days    Male                     12551
# 67   1980    7-27 days  Female                      9217
# 68   1980    7-27 days    Both                     21768
# ...

# %%
# Age Group of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan")['Age Group'].str.endswith("years")]
# Out:
#      Year    Age Group     Sex  Numeric_Number of Deaths  \
# 9    1970    1-4 years    Male                     36694
# 10   1970    1-4 years  Female                     32848
# 11   1970    1-4 years    Both                     69542
# 12   1970    5-9 years    Male                      3467
# 13   1970    5-9 years  Female                      2492
# ..    ...          ...     ...                       ...
# 307  2010  75-79 years  Female                      7679
# 308  2010  75-79 years    Both                     13419
# 309  2010    80+ years    Male                      4865
# 310  2010    80+ years  Female                      6892
# 311  2010    80+ years    Both                     11757
#
#      Numeric_Death Rate Per 100,000
# 9                            4288.2
# 10                           4022.9
# 11                           4158.6
# 12                            396.2
# 13                            306.0
# ..                              ...
# ...

# %%
# Age Group of death in Afghanistan:
Af2=Country_Name("Afghanistan")[Country_Name("Afghanistan")['Age Group'].str.endswith("ages")]
Af2
# Out:
#      Year Age Group     Sex  Numeric_Number of Deaths  \
# 60   1970  All ages    Male                    153656
# 61   1970  All ages  Female                    138181
# 62   1970  All ages    Both                    291837
# 123  1980  All ages    Male                    154935
# 124  1980  All ages  Female                    137110
# 125  1980  All ages    Both                    292045
# 186  1990  All ages    Male                    103305
# 187  1990  All ages  Female                     97331
# 188  1990  All ages    Both                    200636
# 249  2000  All ages    Male                    169558
# 250  2000  All ages  Female                    165558
# 251  2000  All ages    Both                    335117
# 312  2010  All ages    Male                    151509
# 313  2010  All ages  Female                    150654
# 314  2010  All ages    Both                    302163
#
#      Numeric_Death Rate Per 100,000
# 60                           2470.8
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Number of Deaths among the Sexes over Age Group')
sns.barplot(x="Sex", y="Numeric_Number of Deaths", hue="Sex", data=Af2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Number of Deaths among the Sexes over Age Group')
sns.barplot(x="Year", y="Numeric_Number of Deaths", hue="Sex", data=Af2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Sexes over Age Group')
sns.barplot(x="Sex", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Sexes over Age Group')
sns.barplot(x="Year", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af2)

# %%
# Age Group and Sex of death in Afghanistan:
Af3=Country_Name("Afghanistan")[Country_Name("Afghanistan")['Age Group'].str.endswith("days")&(Country_Name("Afghanistan").Sex =='Female')]
Af3
# Out:
#      Year    Age Group     Sex  Numeric_Number of Deaths  \
# 1    1970     0-6 days  Female                     12600
# 4    1970    7-27 days  Female                     11287
# 7    1970  28-364 days  Female                     32113
# 64   1980     0-6 days  Female                     10838
# 67   1980    7-27 days  Female                      9217
# 70   1980  28-364 days  Female                     27191
# 127  1990     0-6 days  Female                      8636
# 130  1990    7-27 days  Female                      6203
# 133  1990  28-364 days  Female                     19286
# 190  2000     0-6 days  Female                     13222
# 193  2000    7-27 days  Female                      9189
# 196  2000  28-364 days  Female                     29421
# 253  2010     0-6 days  Female                     11904
# 256  2010    7-27 days  Female                      5864
# 259  2010  28-364 days  Female                     19657
#
#      Numeric_Death Rate Per 100,000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths verses Numeric_Death Rate Per 100,000 among the Females over the days')
sns.barplot(x="Numeric_Death Rate Per 100,000", y="Numeric_Number of Deaths", hue="Age Group", data=Af3)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths verses Numeric_Death Rate Per 100,000 among the Females over the years')
sns.barplot(x="Numeric_Death Rate Per 100,000", y="Numeric_Number of Deaths", hue="Year", data=Af3)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths among the Females over the days')
sns.barplot(x="Age Group", y="Numeric_Number of Deaths", hue="Sex", data=Af3)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths among the Females over the years')
sns.barplot(x="Year", y="Numeric_Number of Deaths", hue="Sex", data=Af3)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Females over the days')
sns.barplot(x="Age Group", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af3)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Females over the years')
sns.barplot(x="Year", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af3)

# %%
# Age Group and Sex of death in Afghanistan:
Af4=Country_Name("Afghanistan")[Country_Name("Afghanistan")['Age Group'].str.endswith("days")&(Country_Name("Afghanistan").Sex =='Male')]
Af4
# Out:
#      Year    Age Group   Sex  Numeric_Number of Deaths  \
# 0    1970     0-6 days  Male                     19241
# 3    1970    7-27 days  Male                     15939
# 6    1970  28-364 days  Male                     37513
# 63   1980     0-6 days  Male                     16152
# 66   1980    7-27 days  Male                     12551
# 69   1980  28-364 days  Male                     32316
# 126  1990     0-6 days  Male                     12635
# 129  1990    7-27 days  Male                      8325
# 132  1990  28-364 days  Male                     22711
# 189  2000     0-6 days  Male                     19345
# 192  2000    7-27 days  Male                     12365
# 195  2000  28-364 days  Male                     34469
# 252  2010     0-6 days  Male                     17163
# 255  2010    7-27 days  Male                      7639
# 258  2010  28-364 days  Male                     22361
#
#      Numeric_Death Rate Per 100,000
# 0                          318292.9
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths verses Numeric_Death Rate Per 100,000 among the Males over the days')
sns.barplot(x="Numeric_Death Rate Per 100,000", y="Numeric_Number of Deaths", hue="Age Group", data=Af4)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths verses Numeric_Death Rate Per 100,000 among the Males over the years')
sns.barplot(x="Numeric_Death Rate Per 100,000", y="Numeric_Number of Deaths", hue="Year", data=Af4)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths among the Males over the days')
sns.barplot(x="Age Group", y="Numeric_Number of Deaths", hue="Sex", data=Af4)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Number of Deaths among the Males over the years')
sns.barplot(x="Year", y="Numeric_Number of Deaths", hue="Sex", data=Af4)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Males over the days')
sns.barplot(x="Age Group", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af4)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Males over the years')
sns.barplot(x="Year", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af4)

# %%
# Age Group and Sex of death in Afghanistan:
Country_Name("Afghanistan")[Country_Name("Afghanistan")['Age Group'].str.endswith("days")&(Country_Name("Afghanistan").Sex =='Both')]
# Out:
#      Year    Age Group   Sex  Numeric_Number of Deaths  \
# 2    1970     0-6 days  Both                     31840
# 5    1970    7-27 days  Both                     27226
# 8    1970  28-364 days  Both                     69626
# 65   1980     0-6 days  Both                     26991
# 68   1980    7-27 days  Both                     21768
# 71   1980  28-364 days  Both                     59506
# 128  1990     0-6 days  Both                     21271
# 131  1990    7-27 days  Both                     14528
# 134  1990  28-364 days  Both                     41997
# 191  2000     0-6 days  Both                     32567
# 194  2000    7-27 days  Both                     21554
# 197  2000  28-364 days  Both                     63890
# 254  2010     0-6 days  Both                     29067
# 257  2010    7-27 days  Both                     13504
# 260  2010  28-364 days  Both                     42017
#
#      Numeric_Death Rate Per 100,000
# 2                          270200.7
# ...

# %%
# Age Group and Sex of death in Afghanistan:
Af5=Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')]
Af5
# Out:
#      Year Age Group   Sex  Numeric_Number of Deaths  \
# 0    1970  0-6 days  Male                     19241
# 63   1980  0-6 days  Male                     16152
# 126  1990  0-6 days  Male                     12635
# 189  2000  0-6 days  Male                     19345
# 252  2010  0-6 days  Male                     17163
#
#      Numeric_Death Rate Per 100,000
# 0                          318292.9
# 63                         235901.0
# 126                        174654.7
# 189                        168778.1
# 252                        127190.9

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Number of Deaths among the Male')
sns.barplot(x="Year", y="Numeric_Number of Deaths", hue="Sex", data=Af5)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Male')
sns.barplot(x="Year", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af5)

# %%
# Age Group and Sex of death in Afghanistan:
Af6=Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Female')&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')]
Af6
# Out:
#      Year Age Group     Sex  Numeric_Number of Deaths  \
# 1    1970  0-6 days  Female                     12600
# 64   1980  0-6 days  Female                     10838
# 127  1990  0-6 days  Female                      8636
# 190  2000  0-6 days  Female                     13222
# 253  2010  0-6 days  Female                     11904
#
#      Numeric_Death Rate Per 100,000
# 1                          219544.2
# 64                         167053.3
# 127                        126115.8
# 190                        121860.6
# 253                         93233.3

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Number of Deaths among the Females')
sns.barplot(x="Year", y="Numeric_Number of Deaths", hue="Sex", data=Af6)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Females')
sns.barplot(x="Year", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af6)

# %%
# Age Group and Sex of death in Afghanistan:
Af7=Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Both')&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')]
Af7
# Out:
#      Year Age Group   Sex  Numeric_Number of Deaths  \
# 2    1970  0-6 days  Both                     31840
# 65   1980  0-6 days  Both                     26991
# 128  1990  0-6 days  Both                     21271
# 191  2000  0-6 days  Both                     32567
# 254  2010  0-6 days  Both                     29067
#
#      Numeric_Death Rate Per 100,000
# 2                          270200.7
# 65                         202403.9
# 128                        151050.5
# 191                        145956.2
# 254                        110681.5

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Number of Deaths among the Both Sexes')
sns.barplot(x="Year", y="Numeric_Number of Deaths", hue="Sex", data=Af7)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Both Sexes')
sns.barplot(x="Year", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af7)

# %%
# Age Group and Sex of death in Afghanistan:
Af8=Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '7-27 days')]
Af8
# Out:
#      Year  Age Group   Sex  Numeric_Number of Deaths  \
# 3    1970  7-27 days  Male                     15939
# 66   1980  7-27 days  Male                     12551
# 129  1990  7-27 days  Male                      8325
# 192  2000  7-27 days  Male                     12365
# 255  2010  7-27 days  Male                      7639
#
#      Numeric_Death Rate Per 100,000
# 3                           92701.0
# 66                          63362.9
# 129                         39454.3
# 192                         36914.4
# 255                         19244.2

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Number of Deaths among the Male Sexes')
sns.barplot(x="Year", y="Numeric_Number of Deaths", hue="Sex", data=Af8)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 7))
ax.set_title('Plot of Numeric_Death Rate Per 100,000 among the Male Sexes')
sns.barplot(x="Year", y="Numeric_Death Rate Per 100,000", hue="Sex", data=Af8)

# %% [markdown]
# # Summation of Age Group(0-6 days) of Male of Numeric_Number of Deaths in Afghanistan over the years:

# %%
# Summation of Age Group(0-6 days) of Male of Numeric_Number of Deaths in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    84536
# dtype: int64

# %% [markdown]
# # Summation of Age Group(7-27 days) of Male of Numeric_Number of Deaths in Afghanistan over the years:

# %%
# Summation of Age Group(7-27 days) of Male of Numeric_Number of Deaths in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '7-27 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    56819
# dtype: int64

# %% [markdown]
# # Summation of Age Group(28-364 days) of Male of Numeric_Number of Deaths in Afghanistan over the years:

# %%
# Summation of Age Group(28-364 days) of Male of Numeric_Number of Deaths in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '28-364 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    149370
# dtype: int64

# %% [markdown]
# # Summation of Age Group(0-6 days) of Female of Numeric_Number of Deaths in Afghanistan over the yeaars:

# %%
# Summation of Age Group(0-6 days) of Female of Numeric_Number of Deaths in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Female')&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    57200
# dtype: int64

# %% [markdown]
# # Summation of Age Group(7-27 days) of Female of Numeric_Number of Deaths in Afghanistan over the years:

# %%
# Summation of Age Group(7-27 days) of Female of Numeric_Number of Deaths in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Female')&(Country_Name("Afghanistan")['Age Group'] == '7-27 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    41760
# dtype: int64

# %% [markdown]
# # Summation of Age Group(28-364 days) of Female of Numeric_Number of Deaths in Afghanistan over the years:

# %%
# Summation of Age Group(28-364 days) of Female of Numeric_Number of Deaths in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Female')&(Country_Name("Afghanistan")['Age Group'] == '28-364 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    127668
# dtype: int64

# %% [markdown]
# # Summation of Age Group(0-6 days) of Male of Numeric_Death Rate Per 100,000 in Afghanistan over the years:

# %%
# Summation of Age Group(0-6 days) of Male of Numeric_Death Rate Per 100,000 in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '0-6 days')][['Numeric_Death Rate Per 100,000']].sum()
# Out:
# Numeric_Death Rate Per 100,000    1024817.6
# dtype: float64

# %% [markdown]
# # Summation of Age Group(7-27 days) of Male of Numeric_Death Rate Per 100,000 in Afghanistan over the years:

# %%
# Summation of Age Group(7-27 days) of Male of Numeric_Death Rate Per 100,000 in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '7-27 days')][['Numeric_Death Rate Per 100,000']].sum()
# Out:
# Numeric_Death Rate Per 100,000    251676.8
# dtype: float64

# %% [markdown]
# # Summation of Age Group(28-364 days) of Male of Numeric_Death Rate Per 100,000 in Afghanistan over the years:

# %%
# Summation of Age Group(7-27 days) of Male of Numeric_Death Rate Per 100,000 in Afghanistan:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Sex =='Male')&(Country_Name("Afghanistan")['Age Group'] == '28-364 days')][['Numeric_Death Rate Per 100,000']].sum()
# Out:
# Numeric_Death Rate Per 100,000    43350.6
# dtype: float64

# %% [markdown]
# # Summation of Numeric_Number of Deaths of  all Age Groups of Male in Afghanistan in 1970:

# %%
# Year and Sex of death in Afghanistan in 1970:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Male')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    307312
# dtype: int64

# %% [markdown]
# # Summation of Numeric_Death Rate Per 100,000 of all Age Groups of Male in Afghanistan in 1970:

# %%
# Year and Sex of death in Afghanistan in 1970:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Male')][['Numeric_Death Rate Per 100,000']].sum()
# Out:
# Numeric_Death Rate Per 100,000    492041.4
# dtype: float64

# %% [markdown]
# # Summation of Numeric_Number of Deaths of all Age Groups of Female in Afghanistan in 1970:

# %%
# Year and Sex of death in Afghanistan in 1970:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Female')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    276361
# dtype: int64

# %% [markdown]
# # Summation of Numeric_Death Rate Per 100,000 of all Age Groups of Female in Afghanistan in 1970:

# %%
# Year and Sex of death in Afghanistan in 1970:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Female')][['Numeric_Death Rate Per 100,000']].sum()
# Out:
# Numeric_Death Rate Per 100,000    376140.4
# dtype: float64

# %% [markdown]
# # Summation of Numeric_Death Rate Per 100,000 of all Age Groups of Both Sexes in Afghanistan in 1970:

# %%
# Year and Sex of death in Afghanistan in 1970:
Country_Name("Afghanistan")[(Country_Name("Afghanistan").Year == 1970)&(Country_Name("Afghanistan").Sex =='Both')] [['Numeric_Death Rate Per 100,000']].sum()
# Out:
# Numeric_Death Rate Per 100,000    435797.7
# dtype: float64

# %% [markdown]
# # Analysis of data from Nigeria

# %%
Country_Name("Nigeria")
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38745  1970   0-6 days    Male                     75559
# 38746  1970   0-6 days  Female                     47523
# 38747  1970   0-6 days    Both                    123082
# 38748  1970  7-27 days    Male                     31074
# 38749  1970  7-27 days  Female                     22657
# ...     ...        ...     ...                       ...
# 39055  2010  80+ years  Female                     39353
# 39056  2010  80+ years    Both                     67448
# 39057  2010   All ages    Male                    861754
# 39058  2010   All ages  Female                    779636
# 39059  2010   All ages    Both                   1641390
#
#        Numeric_Death Rate Per 100,000
# 38745                        297136.2
# 38746                        196578.1
# 38747                        248128.2
# 38748                         42363.5
# 38749                         32232.5
# ...                               ...
# ...

# %%
# People that are Males i Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Sex == 'Male']
# Out:
#        Year    Age Group   Sex  Numeric_Number of Deaths  \
# 38745  1970     0-6 days  Male                     75559
# 38748  1970    7-27 days  Male                     31074
# 38751  1970  28-364 days  Male                     97328
# 38754  1970    1-4 years  Male                    186704
# 38757  1970    5-9 years  Male                     14954
# ...     ...          ...   ...                       ...
# 39045  2010  65-69 years  Male                     28194
# 39048  2010  70-74 years  Male                     28957
# 39051  2010  75-79 years  Male                     24784
# 39054  2010    80+ years  Male                     28095
# 39057  2010     All ages  Male                    861754
#
#        Numeric_Death Rate Per 100,000
# 38745                        297136.2
# 38748                         42363.5
# 38751                          8801.0
# 38754                          4810.1
# 38757                           375.5
# ...                               ...
# ...

# %%
# People that are Females i Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Sex == 'Female']
# Out:
#        Year    Age Group     Sex  Numeric_Number of Deaths  \
# 38746  1970     0-6 days  Female                     47523
# 38749  1970    7-27 days  Female                     22657
# 38752  1970  28-364 days  Female                     75339
# 38755  1970    1-4 years  Female                    151218
# 38758  1970    5-9 years  Female                     11682
# ...     ...          ...     ...                       ...
# 39046  2010  65-69 years  Female                     34417
# 39049  2010  70-74 years  Female                     33532
# 39052  2010  75-79 years  Female                     30195
# 39055  2010    80+ years  Female                     39353
# 39058  2010     All ages  Female                    779636
#
#        Numeric_Death Rate Per 100,000
# 38746                        196578.1
# 38749                         32232.5
# 38752                          7074.8
# 38755                          4016.8
# 38758                           299.0
# ...

# %%
# People that are Both sexes i Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Sex == 'Both']
# Out:
#        Year    Age Group   Sex  Numeric_Number of Deaths  \
# 38747  1970     0-6 days  Both                    123082
# 38750  1970    7-27 days  Both                     53731
# 38753  1970  28-364 days  Both                    172667
# 38756  1970    1-4 years  Both                    337922
# 38759  1970    5-9 years  Both                     26636
# ...     ...          ...   ...                       ...
# 39047  2010  65-69 years  Both                     62610
# 39050  2010  70-74 years  Both                     62489
# 39053  2010  75-79 years  Both                     54979
# 39056  2010    80+ years  Both                     67448
# 39059  2010     All ages  Both                   1641390
#
#        Numeric_Death Rate Per 100,000
# 38747                        248128.2
# 38750                         37405.8
# 38753                          7954.2
# 38756                          4419.5
# 38759                           337.7
# ...                               ...
# ...

# %%
# 1970 Year of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Year == 1970]
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38745  1970   0-6 days    Male                     75559
# 38746  1970   0-6 days  Female                     47523
# 38747  1970   0-6 days    Both                    123082
# 38748  1970  7-27 days    Male                     31074
# 38749  1970  7-27 days  Female                     22657
# ...     ...        ...     ...                       ...
# 38803  1970  80+ years  Female                     13378
# 38804  1970  80+ years    Both                     20975
# 38805  1970   All ages    Male                    540386
# 38806  1970   All ages  Female                    472467
# 38807  1970   All ages    Both                   1012853
#
#        Numeric_Death Rate Per 100,000
# 38745                        297136.2
# 38746                        196578.1
# 38747                        248128.2
# 38748                         42363.5
# 38749                         32232.5
# ...                               ...
# ...

# %%
# 1980 Year of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Year == 1980]
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38808  1980   0-6 days    Male                     81666
# 38809  1980   0-6 days  Female                     52873
# 38810  1980   0-6 days    Both                    134539
# 38811  1980  7-27 days    Male                     31496
# 38812  1980  7-27 days  Female                     23487
# ...     ...        ...     ...                       ...
# 38866  1980  80+ years  Female                     18507
# 38867  1980  80+ years    Both                     30046
# 38868  1980   All ages    Male                    576409
# 38869  1980   All ages  Female                    503775
# 38870  1980   All ages    Both                   1080184
#
#        Numeric_Death Rate Per 100,000
# 38808                        239301.4
# 38809                        163191.8
# 38810                        202238.1
# 38811                         31749.7
# 38812                         24780.9
# ...                               ...
# ...

# %%
# 1990 Year of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Year == 1990]
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38871  1990   0-6 days    Male                     97684
# 38872  1990   0-6 days  Female                     63329
# 38873  1990   0-6 days    Both                    161013
# 38874  1990  7-27 days    Male                     37516
# 38875  1990  7-27 days  Female                     27998
# ...     ...        ...     ...                       ...
# 38929  1990  80+ years  Female                     23731
# 38930  1990  80+ years    Both                     38982
# 38931  1990   All ages    Male                    709133
# 38932  1990   All ages  Female                    618349
# 38933  1990   All ages    Both                   1327482
#
#        Numeric_Death Rate Per 100,000
# 38871                        236630.8
# 38872                        161603.1
# 38873                        200092.7
# 38874                         31241.1
# 38875                         24407.4
# ...                               ...
# ...

# %%
# 2000 Year of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Year == 2000]
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38934  2000   0-6 days    Male                    109212
# 38935  2000   0-6 days  Female                     71561
# 38936  2000   0-6 days    Both                    180772
# 38937  2000  7-27 days    Male                     40216
# 38938  2000  7-27 days  Female                     30154
# ...     ...        ...     ...                       ...
# 38992  2000  80+ years  Female                     30013
# 38993  2000  80+ years    Both                     49707
# 38994  2000   All ages    Male                    840473
# 38995  2000   All ages  Female                    753659
# 38996  2000   All ages    Both                   1594133
#
#        Numeric_Death Rate Per 100,000
# 38934                        217540.0
# 38935                        150220.6
# 38936                        184761.2
# 38937                         27470.1
# 38938                         21582.3
# ...                               ...
# ...

# %%
# 2010 Year of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria").Year == 2010]
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38997  2010   0-6 days    Male                    111802
# 38998  2010   0-6 days  Female                     74679
# 38999  2010   0-6 days    Both                    186481
# 39000  2010  7-27 days    Male                     35718
# 39001  2010  7-27 days  Female                     26714
# ...     ...        ...     ...                       ...
# 39055  2010  80+ years  Female                     39353
# 39056  2010  80+ years    Both                     67448
# 39057  2010   All ages    Male                    861754
# 39058  2010   All ages  Female                    779636
# 39059  2010   All ages    Both                   1641390
#
#        Numeric_Death Rate Per 100,000
# 38997                        182031.7
# 38998                        128239.2
# 38999                        155851.4
# 39000                         19835.9
# 39001                         15573.5
# ...                               ...
# ...

# %%
# Year,age group ,and Sex(Male) of death in Nigeria:
Country_Name("Nigeria")[(Country_Name("Nigeria").Year == 1970)&(Country_Name("Nigeria")['Age Group'] == '0-6 days')&(Country_Name("Nigeria").Sex =='Male')]
# Out:
#        Year Age Group   Sex  Numeric_Number of Deaths  \
# 38745  1970  0-6 days  Male                     75559
#
#        Numeric_Death Rate Per 100,000
# 38745                        297136.2

# %%
# Year and age group of death in Nigeria:
Country_Name("Nigeria")[(Country_Name("Nigeria").Year == 1970)&(Country_Name("Nigeria")['Age Group'] == '0-6 days')]
# Out:
#        Year Age Group     Sex  Numeric_Number of Deaths  \
# 38745  1970  0-6 days    Male                     75559
# 38746  1970  0-6 days  Female                     47523
# 38747  1970  0-6 days    Both                    123082
#
#        Numeric_Death Rate Per 100,000
# 38745                        297136.2
# 38746                        196578.1
# 38747                        248128.2

# %%
# Year and age group(7-27 days) of death in Nigeria:
Country_Name("Nigeria")[(Country_Name("Nigeria").Year == 1970)&(Country_Name("Nigeria")['Age Group'] == '7-27 days')]
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38748  1970  7-27 days    Male                     31074
# 38749  1970  7-27 days  Female                     22657
# 38750  1970  7-27 days    Both                     53731
#
#        Numeric_Death Rate Per 100,000
# 38748                         42363.5
# 38749                         32232.5
# 38750                         37405.8

# %%
# Year and Sex(Male) of death in Nigeria in 1970:
N1=Country_Name("Nigeria")[(Country_Name("Nigeria").Year == 1970)&(Country_Name("Nigeria").Sex =='Male')]
N1
# Out:
#        Year    Age Group   Sex  Numeric_Number of Deaths  \
# 38745  1970     0-6 days  Male                     75559
# 38748  1970    7-27 days  Male                     31074
# 38751  1970  28-364 days  Male                     97328
# 38754  1970    1-4 years  Male                    186704
# 38757  1970    5-9 years  Male                     14954
# 38760  1970  10-14 years  Male                      6117
# 38763  1970  15-19 years  Male                      5456
# 38766  1970  20-24 years  Male                      7121
# 38769  1970  25-29 years  Male                      7296
# 38772  1970  30-34 years  Male                      6995
# 38775  1970  35-39 years  Male                      7129
# 38778  1970  40-44 years  Male                      7627
# 38781  1970  45-49 years  Male                      8724
# 38784  1970  50-54 years  Male                     10145
# 38787  1970  55-59 years  Male                     11068
# ...

# %%
# Year and Sex(Female) of death in Nigeria in 1970:
N2=Country_Name("Nigeria")[(Country_Name("Nigeria").Year == 1970)&(Country_Name("Nigeria").Sex =='Female')]
N2
# Out:
#        Year    Age Group     Sex  Numeric_Number of Deaths  \
# 38746  1970     0-6 days  Female                     47523
# 38749  1970    7-27 days  Female                     22657
# 38752  1970  28-364 days  Female                     75339
# 38755  1970    1-4 years  Female                    151218
# 38758  1970    5-9 years  Female                     11682
# 38761  1970  10-14 years  Female                      5487
# 38764  1970  15-19 years  Female                      6069
# 38767  1970  20-24 years  Female                      7934
# 38770  1970  25-29 years  Female                      8788
# 38773  1970  30-34 years  Female                      8677
# 38776  1970  35-39 years  Female                      9401
# 38779  1970  40-44 years  Female                      8777
# 38782  1970  45-49 years  Female                      9138
# 38785  1970  50-54 years  Female                     10636
# 38788  1970  55-59 years  Female                     11501
# ...

# %%
# Year and Sex(Both) of death in Nigeria in 1970:
N3=Country_Name("Nigeria")[(Country_Name("Nigeria").Year == 1970)&(Country_Name("Nigeria").Sex =='Both')]
N3
# Out:
#        Year    Age Group   Sex  Numeric_Number of Deaths  \
# 38747  1970     0-6 days  Both                    123082
# 38750  1970    7-27 days  Both                     53731
# 38753  1970  28-364 days  Both                    172667
# 38756  1970    1-4 years  Both                    337922
# 38759  1970    5-9 years  Both                     26636
# 38762  1970  10-14 years  Both                     11604
# 38765  1970  15-19 years  Both                     11525
# 38768  1970  20-24 years  Both                     15055
# 38771  1970  25-29 years  Both                     16084
# 38774  1970  30-34 years  Both                     15672
# 38777  1970  35-39 years  Both                     16530
# 38780  1970  40-44 years  Both                     16404
# 38783  1970  45-49 years  Both                     17862
# 38786  1970  50-54 years  Both                     20781
# 38789  1970  55-59 years  Both                     22569
# ...

# %%
# Age Group of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria")['Age Group'].str.endswith("days")]
# Out:
#        Year    Age Group     Sex  Numeric_Number of Deaths  \
# 38745  1970     0-6 days    Male                     75559
# 38746  1970     0-6 days  Female                     47523
# 38747  1970     0-6 days    Both                    123082
# 38748  1970    7-27 days    Male                     31074
# 38749  1970    7-27 days  Female                     22657
# 38750  1970    7-27 days    Both                     53731
# 38751  1970  28-364 days    Male                     97328
# 38752  1970  28-364 days  Female                     75339
# 38753  1970  28-364 days    Both                    172667
# 38808  1980     0-6 days    Male                     81666
# 38809  1980     0-6 days  Female                     52873
# 38810  1980     0-6 days    Both                    134539
# 38811  1980    7-27 days    Male                     31496
# 38812  1980    7-27 days  Female                     23487
# 38813  1980    7-27 days    Both                     54983
# ...

# %%
# Age Group of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria")['Age Group'].str.endswith("years")]
# Out:
#        Year    Age Group     Sex  Numeric_Number of Deaths  \
# 38754  1970    1-4 years    Male                    186704
# 38755  1970    1-4 years  Female                    151218
# 38756  1970    1-4 years    Both                    337922
# 38757  1970    5-9 years    Male                     14954
# 38758  1970    5-9 years  Female                     11682
# ...     ...          ...     ...                       ...
# 39052  2010  75-79 years  Female                     30195
# 39053  2010  75-79 years    Both                     54979
# 39054  2010    80+ years    Male                     28095
# 39055  2010    80+ years  Female                     39353
# 39056  2010    80+ years    Both                     67448
#
#        Numeric_Death Rate Per 100,000
# 38754                          4810.1
# 38755                          4016.8
# 38756                          4419.5
# 38757                           375.5
# 38758                           299.0
# ...

# %%
# Age Group of death in Nigeria:
Country_Name("Nigeria")[Country_Name("Nigeria")['Age Group'].str.endswith("ages")]
# Out:
#        Year Age Group     Sex  Numeric_Number of Deaths  \
# 38805  1970  All ages    Male                    540386
# 38806  1970  All ages  Female                    472467
# 38807  1970  All ages    Both                   1012853
# 38868  1980  All ages    Male                    576409
# 38869  1980  All ages  Female                    503775
# 38870  1980  All ages    Both                   1080184
# 38931  1990  All ages    Male                    709133
# 38932  1990  All ages  Female                    618349
# 38933  1990  All ages    Both                   1327482
# 38994  2000  All ages    Male                    840473
# 38995  2000  All ages  Female                    753659
# 38996  2000  All ages    Both                   1594133
# 39057  2010  All ages    Male                    861754
# 39058  2010  All ages  Female                    779636
# 39059  2010  All ages    Both                   1641390
#
#        Numeric_Death Rate Per 100,000
# ...

# %%
# Age Group and Sex of death in Nigeria:
N4=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Male')&(Country_Name("Nigeria")['Age Group'] == '0-6 days')]
N4
# Out:
#        Year Age Group   Sex  Numeric_Number of Deaths  \
# 38745  1970  0-6 days  Male                     75559
# 38808  1980  0-6 days  Male                     81666
# 38871  1990  0-6 days  Male                     97684
# 38934  2000  0-6 days  Male                    109212
# 38997  2010  0-6 days  Male                    111802
#
#        Numeric_Death Rate Per 100,000
# 38745                        297136.2
# 38808                        239301.4
# 38871                        236630.8
# 38934                        217540.0
# 38997                        182031.7

# %%
# Age Group and Sex of death in Nigeria:
N5=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Male')&(Country_Name("Nigeria")['Age Group'] == '7-27 days')]
N5
# Out:
#        Year  Age Group   Sex  Numeric_Number of Deaths  \
# 38748  1970  7-27 days  Male                     31074
# 38811  1980  7-27 days  Male                     31496
# 38874  1990  7-27 days  Male                     37516
# 38937  2000  7-27 days  Male                     40216
# 39000  2010  7-27 days  Male                     35718
#
#        Numeric_Death Rate Per 100,000
# 38748                         42363.5
# 38811                         31749.7
# 38874                         31241.1
# 38937                         27470.1
# 39000                         19835.9

# %%
# Age Group and Sex of death in Nigeria:
N6=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Male')&(Country_Name("Nigeria")['Age Group'] == '28-364 days')]
N6
# Out:
#        Year    Age Group   Sex  Numeric_Number of Deaths  \
# 38751  1970  28-364 days  Male                     97328
# 38814  1980  28-364 days  Male                    104553
# 38877  1990  28-364 days  Male                    125504
# 38940  2000  28-364 days  Male                    137201
# 39003  2010  28-364 days  Male                    127964
#
#        Numeric_Death Rate Per 100,000
# 38751                          8801.0
# 38814                          6910.1
# 38877                          6816.9
# 38940                          6107.5
# 39003                          4586.6

# %%
# Age Group and Sex of death in Nigeria:
N7=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Male')&(Country_Name("Nigeria")['Age Group'] == '1-4 years')]
N7
# Out:
#        Year  Age Group   Sex  Numeric_Number of Deaths  \
# 38754  1970  1-4 years  Male                    186704
# 38817  1980  1-4 years  Male                    188313
# 38880  1990  1-4 years  Male                    230315
# 38943  2000  1-4 years  Male                    239730
# 39006  2010  1-4 years  Male                    205538
#
#        Numeric_Death Rate Per 100,000
# 38754                          4810.1
# 38817                          3467.3
# 38880                          3365.6
# 38943                          2900.7
# 39006                          1914.5

# %%
# Age Group and Sex of death in Nigeria:
N8=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Female')&(Country_Name("Nigeria")['Age Group'] == '0-6 days')]
N8
# Out:
#        Year Age Group     Sex  Numeric_Number of Deaths  \
# 38746  1970  0-6 days  Female                     47523
# 38809  1980  0-6 days  Female                     52873
# 38872  1990  0-6 days  Female                     63329
# 38935  2000  0-6 days  Female                     71561
# 38998  2010  0-6 days  Female                     74679
#
#        Numeric_Death Rate Per 100,000
# 38746                        196578.1
# 38809                        163191.8
# 38872                        161603.1
# 38935                        150220.6
# 38998                        128239.2

# %%
# Age Group and Sex of death in Nigeria:
N9=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Female')&(Country_Name("Nigeria")['Age Group'] == '7-27 days')]
N9
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38749  1970  7-27 days  Female                     22657
# 38812  1980  7-27 days  Female                     23487
# 38875  1990  7-27 days  Female                     27998
# 38938  2000  7-27 days  Female                     30154
# 39001  2010  7-27 days  Female                     26714
#
#        Numeric_Death Rate Per 100,000
# 38749                         32232.5
# 38812                         24780.9
# 38875                         24407.4
# 38938                         21582.3
# 39001                         15573.5

# %%
# Age Group and Sex of death in Nigeria:
N10=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Female')&(Country_Name("Nigeria")['Age Group'] == '28-364 days')]
N10
# Out:
#        Year    Age Group     Sex  Numeric_Number of Deaths  \
# 38752  1970  28-364 days  Female                     75339
# 38815  1980  28-364 days  Female                     80730
# 38878  1990  28-364 days  Female                     96902
# 38941  2000  28-364 days  Female                    106377
# 39004  2010  28-364 days  Female                    101757
#
#        Numeric_Death Rate Per 100,000
# 38752                          7074.8
# 38815                          5563.4
# 38878                          5489.9
# 38941                          4945.2
# 39004                          3820.6

# %%
# Age Group and Sex of death in Nigeria:
N11=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Female')&(Country_Name("Nigeria")['Age Group'] == '1-4 years')]
N11
# Out:
#        Year  Age Group     Sex  Numeric_Number of Deaths  \
# 38755  1970  1-4 years  Female                    151218
# 38818  1980  1-4 years  Female                    151916
# 38881  1990  1-4 years  Female                    185288
# 38944  2000  1-4 years  Female                    192952
# 39007  2010  1-4 years  Female                    163034
#
#        Numeric_Death Rate Per 100,000
# 38755                          4016.8
# 38818                          2898.4
# 38881                          2810.0
# 38944                          2424.0
# 39007                          1586.6

# %%
# Age Group and Sex of death in Nigeria:
N12=Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Both')&(Country_Name("Nigeria")['Age Group'] == '0-6 days')]
N12
# Out:
#        Year Age Group   Sex  Numeric_Number of Deaths  \
# 38747  1970  0-6 days  Both                    123082
# 38810  1980  0-6 days  Both                    134539
# 38873  1990  0-6 days  Both                    161013
# 38936  2000  0-6 days  Both                    180772
# 38999  2010  0-6 days  Both                    186481
#
#        Numeric_Death Rate Per 100,000
# 38747                        248128.2
# 38810                        202238.1
# 38873                        200092.7
# 38936                        184761.2
# 38999                        155851.4

# %% [markdown]
# # Summation of Age Group(0-6 days) of Male of Numeric_Number of Deaths in Nigeria over the years:

# %%
# Summation of Age Group(0-6 days) of Male of Numeric_Number of Deaths in Nigeria:
Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Male')&(Country_Name("Nigeria")['Age Group'] == '0-6 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    475923
# dtype: int64

# %% [markdown]
# # Summation of Age Group(7-27 days) of Male of Numeric_Number of Deaths in Nigeria over the years:

# %%
# Summation of Age Group(7-27 days) of Male of Numeric_Number of Deaths in Nigeria:
Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Male')&(Country_Name("Nigeria")['Age Group'] == '7-27 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    176020
# dtype: int64

# %% [markdown]
# # Summation of Age Group(28-364 days) of Male of Numeric_Number of Deaths in Nigeria over the years:

# %%
# Summation of Age Group(28-364 days) of Male of Numeric_Number of Deaths in Nigeria:
Country_Name("Nigeria")[(Country_Name("Nigeria").Sex =='Male')&(Country_Name("Nigeria")['Age Group'] == '28-364 days')][['Numeric_Number of Deaths']].sum()
# Out:
# Numeric_Number of Deaths    592550
# dtype: int64
